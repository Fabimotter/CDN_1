# %% [markdown]
# <a href="https://colab.research.google.com/github/Fabimotter/CDN_1/blob/main/Aula_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
idade = int(input("Qual é a sua idade:"))
if idade >= 18:
    print("Parabéns, você já é maior de idade!!")
else:
    print("Espere um pouco mais")
# Out:
# Qual é a sua idade:43
# Parabéns, você já é maior de idade!!
