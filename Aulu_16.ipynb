# %% [markdown]
# <a href="https://colab.research.google.com/github/Fabimotter/CDN_1/blob/main/Aulu_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome="Maria"
idade=25
print (nome, " tem ", idade, " anos ")
# Out:
# Maria  tem  25  anos

# %%
x=input("Digite o valor de x: ")
y=input("Digite o valor de y: ")
print ("Resutado da soma:", x+y)
# Out:
# Digite o valor de x: 1
# Digite o valor de y: 2
# Resutado da soma: 12

# %%
x=int(input("Digite o valor de x: "))
y= int(input("Digite o valor de y: "))
print ("Resutado da soma:", x+y)
# Out:
# Digite o valor de x: 1
# Digite o valor de y: 2
# Resutado da soma: 3

# %%
"""Esta linha é um comentário"""
# Out:
# 'Esta linha é um comentário'
