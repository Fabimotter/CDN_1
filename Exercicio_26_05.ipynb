# %%
# Valor do RA
RA = 18

print("RA informado:", RA)


# Exercício 1
def total (cabecas, pes):
    coelhos = (pes - 2 * cabecas) // 2
    patos = cabecas - coelhos
    return int(patos), int(coelhos)


Y = RA
cabecas = Y
pes = Y * 3

patos, coelhos = calcular_patos_coelhos(cabecas, pes)


print("Total de Cabeças =", cabecas)
print("Total de Pés =", pes)
print("Total de Patos =", patos)
print("Total de Coelhos =", coelhos)
# Out:
# RA informado: 18
# Total de Cabeças = 18
# Total de Pés = 54
# Total de Patos = 9
# Total de Coelhos = 9

# %%
# Exercício 2
ra_texto = str(RA)

soma = 0
multiplicacao = 1

for digito in ra_texto:
    numero = int(digito)
    soma = soma + numero
    multiplicacao = multiplicacao * numero

print("Soma =", soma)
print("Multiplicação =", multiplicacao)
# Out:
# Soma = 9
# Multiplicação = 8

# %%
# Exercício 3
def reverso_numero(numero):
    numero_texto = str(numero)
    reverso = numero_texto[::-1]
    return reverso


reverso = reverso_numero(RA)
print("RA reverso =", reverso)
# Out:
# RA reverso = 81
